# %% [markdown]
# # Data Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from sklearn.datasets import make_multilabel_classification
# %load_ext tensorboard

# %%
data = np.loadtxt("data.txt")
data_df = pd.read_csv("data.txt", sep=" ",
                      names=["distance_to_ground",
                             "x_diff",
                            "over_lz",
                            "dx",
                            "dy",
                            "safe_speed",
                            "tilt",
                            "safe_tilt",
                            "rotation",
                            "time_since_thrust",
                            "time_since_tilt",
                            "W",
                            "A",
                            "D"])

def speed(row):
    return np.sqrt(row["dx"]**2 + row["dy"]**2)

def any_pressed(row):
    return int(row["W"] == 0 and row["A"] == 0 and row["D"] == 0)

def target_vec(row):
    return [row["W"], row["A"], row["D"], row["Not_pressed"]]

data_df["Not_pressed"] = data_df.apply(any_pressed, axis=1)
data_df["Speed"] = data_df.apply(speed, axis=1)

data_df[(data_df["W"] != 0) & (data_df["A"] != 0)]
# Out:
#        distance_to_ground     x_diff  over_lz        dx         dy  \
# 1337           126.720093  31.080078        1  0.094044  63.292709
# 1338           125.412842  31.081665        1  0.102700  62.862968
# 1339           124.386230  31.083679        1  0.114380  62.331120
# 1340           123.227661  31.085876        1  0.127457  61.777687
# 1341           122.124146  31.088440        1  0.142696  61.171474
# ...                   ...        ...      ...       ...        ...
# 36585           18.270508  -4.270691        1  6.137001  17.756762
# 36586           17.996338  -4.160828        1  6.163894  17.400999
# 36587           17.703735  -4.050476        1  6.192720  17.009644
# 36588           17.435791  -3.939209        1  6.223519  16.581230
# 36589           17.192505  -3.827698        1  6.255991  16.118679
#
#        safe_speed      tilt  safe_tilt  rotation  time_since_thrust  \
# 1337            0  2.487534          1      10.0                0.0
# 1338            0  2.610367          1       8.0                0.0
# 1339            0  2.716785          1       6.0                0.0
# 1340            0  2.785999          1       4.0                0.0
# 1341            0  2.821678          1       2.0                0.0
# ...           ...       ...        ...       ...                ...
# 36585           1  3.216187          1       0.0                0.0
# 36586           1  3.180542          1      -2.0                0.0
# 36587           1  3.109253          1      -4.0                0.0
# 36588           1  3.001953          1      -6.0                0.0
# 36589           1  2.859375          1      -8.0                0.0
#
#        time_since_tilt  W  A  D  Not_pressed      Speed
# 1337               0.0  1  1  0            0  63.292779
# 1338               0.0  1  1  0            0  62.863052
# 1339               0.0  1  1  0            0  62.331225
# 1340               0.0  1  1  0            0  61.777818
# 1341               0.0  1  1  0            0  61.171640
# ...                ... .. .. ..          ...        ...
# 36585              0.0  1  1  0            0  18.787373
# 36586              0.0  1  1  0            0  18.460454
# 36587              0.0  1  1  0            0  18.101872
# 36588              0.0  1  1  0            0  17.710714
# 36589              0.0  1  1  0            0  17.290149
#
# [330 rows x 16 columns]

# %%
data_df.corr().style.background_gradient(cmap=plt.get_cmap("RdYlGn"))
# Out:
# <style  type="text/css" >
#     #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow0_col0 {
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow0_col1 {
#             background-color:  #fedc88;
#             color:  #000000;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow0_col2 {
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow0_col3 {
#             background-color:  #fca85e;
#             color:  #000000;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow0_col4 {
#             background-color:  #daf08d;
#             color:  #000000;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow0_col5 {
#             background-color:  #fdc574;
#             color:  #000000;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow0_col6 {
#             background-color:  #fdaf62;
#             color:  #000000;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow0_col7 {
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow0_col8 {
#             background-color:  #ef633f;
#             color:  #000000;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow0_col9 {
#             background-color:  #e0f295;
#             color:  #000000;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow0_col10 {
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow0_col11 {
#             background-color:  #fcaa5f;
#             color:  #000000;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow0_col12 {
#             background-color:  #fb9d59;
#             color:  #000000;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow0_col13 {
#             background-color:  #fb9d59;
#             color:  #000000;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow0_col14 {
#             background-color:  #f2faae;
#             color:  #000000;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow0_col15 {
#             background-color:  #e2f397;
#             color:  #000000;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow1_col0 {
#             background-color:  #fed683;
#             color:  #000000;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow1_col1 {
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow1_col2 {
#             background-color:  #fdc574;
#             color:  #000000;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow1_col3 {
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow1_col4 {
#             background-color:  #fff2aa;
#             color:  #000000;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow1_col5 {
#             background-color:  #feefa3;
#             color:  #000000;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow1_col6 {
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow1_col7 {
#             background-color:  #f57547;
#             color:  #000000;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow1_col8 {
#             background-color:  #f16640;
#             color:  #000000;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow1_col9 {
#             background-color:  #fede89;
#             color:  #000000;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow1_col10 {
#             background-color:  #dd3d2d;
#             color:  #f1f1f1;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow1_col11 {
#             background-color:  #fee28f;
#             color:  #000000;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow1_col12 {
#             background-color:  #f7844e;
#             color:  #000000;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow1_col13 {
#             background-color:  #f88950;
#             color:  #000000;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow1_col14 {
#             background-color:  #fff2aa;
#             color:  #000000;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow1_col15 {
#             background-color:  #fffab6;
#             color:  #000000;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow2_col0 {
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow2_col1 {
#             background-color:  #feca79;
#             color:  #000000;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow2_col2 {
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow2_col3 {
#             background-color:  #fec877;
#             color:  #000000;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow2_col4 {
#             background-color:  #fdb96a;
#             color:  #000000;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow2_col5 {
#             background-color:  #d3ec87;
#             color:  #000000;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow2_col6 {
#             background-color:  #fdbd6d;
#             color:  #000000;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow2_col7 {
#             background-color:  #abdb6d;
#             color:  #000000;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow2_col8 {
#             background-color:  #f26841;
#             color:  #000000;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow2_col9 {
#             background-color:  #f36b42;
#             color:  #000000;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow2_col10 {
#             background-color:  #feda86;
#             color:  #000000;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow2_col11 {
#             background-color:  #fffab6;
#             color:  #000000;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow2_col12 {
#             background-color:  #f7844e;
#             color:  #000000;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow2_col13 {
#             background-color:  #f7814c;
#             color:  #000000;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow2_col14 {
#             background-color:  #fee28f;
#             color:  #000000;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow2_col15 {
#             background-color:  #fdad60;
#             color:  #000000;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow3_col0 {
#             background-color:  #fb9d59;
#             color:  #000000;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow3_col1 {
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow3_col2 {
#             background-color:  #fdc372;
#             color:  #000000;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow3_col3 {
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow3_col4 {
#             background-color:  #fee28f;
#             color:  #000000;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow3_col5 {
#             background-color:  #f4fab0;
#             color:  #000000;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow3_col6 {
#             background-color:  #fdb96a;
#             color:  #000000;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow3_col7 {
#             background-color:  #f7814c;
#             color:  #000000;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow3_col8 {
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow3_col9 {
#             background-color:  #f57245;
#             color:  #000000;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow3_col10 {
#             background-color:  #db382b;
#             color:  #f1f1f1;
#         }    #T_affd02ce_bbdd_11eb_b9fd_a483e7105fbarow3_col11 {
#             background-color:  #feefa3;

# %%
#data_df.plot("x_diff", "distance_to_ground", kind="scatter", c="Speed", cmap='RdYlGn')

# %%
#data_df.plot("x_diff", "distance_to_ground", kind="scatter", c="tilt", cmap='RdYlGn')

# %%
#data_df.plot("x_diff", "distance_to_ground", kind="scatter", c="time_since_thrust", cmap='RdYlGn')

# %% [markdown]
# ## NN training

# %%
data_df.dtypes
# Out:
# distance_to_ground    float64
# x_diff                float64
# over_lz                 int64
# dx                    float64
# dy                    float64
# safe_speed              int64
# tilt                  float64
# safe_tilt               int64
# rotation              float64
# time_since_thrust     float64
# time_since_tilt       float64
# W                       int64
# A                       int64
# D                       int64
# Not_pressed             int64
# Speed                 float64
# dtype: object

# %%
features = data_df
features = features.drop(columns=["W", "A", "D", "Not_pressed"])

labels = data_df
labels = labels.drop(columns=["distance_to_ground",
                             "x_diff",
                            "over_lz",
                            "dx",
                            "dy",
                            "safe_speed",
                            "tilt",
                            "safe_tilt",
                            "rotation",
                            "time_since_thrust",
                            "time_since_tilt",
                            "Speed"])

# %%
# Imports
from sklearn.datasets import make_multilabel_classification
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.optimizers import Adam

# Configuration options
n_samples = 10000
n_features = 6
n_classes = 3
n_labels = 2
n_epochs = 50
random_state = 42
batch_size = 250
verbosity = 1
validation_split = 0.2

# Create dataset
X, y = make_multilabel_classification(n_samples=n_samples, n_features=n_features, n_classes=n_classes, n_labels=n_labels, random_state=random_state)

print(np.shape(X))
print(np.shape(y))

# Split into training and testing data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=random_state)

print(np.shape(X_train))
print(np.shape(X_test))
print(np.shape(y_train))
print(np.shape(y_test))

# Create the model
model = Sequential()
model.add(Dense(32, activation='relu', input_dim=n_features))
model.add(Dense(16, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(n_classes, activation='sigmoid'))

# Compile the model
model.compile(loss=binary_crossentropy,
              optimizer=Adam(),
              metrics=['accuracy'])

# Fit data to model
#model.fit(X_train, y_train,
#          batch_size=batch_size,
#          epochs=n_epochs,
#          verbose=verbosity,
#          validation_split=validation_split)

# Generate generalization metrics
score = model.evaluate(X_test, y_test, verbose=0)
print(f'Test loss: {score[0]} / Test accuracy: {score[1]}')
# Out:
# (10000, 6)
# (10000, 3)
# (6700, 6)
# (3300, 6)
# (6700, 3)
# (3300, 3)
# Test loss: 0.776869530244307 / Test accuracy: 0.5071717500686646

# %%
X = features.to_numpy()

y = labels.to_numpy()

# Split into training and testing data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=random_state)

# %%
def get_compiled_model():
    #Create the model
    model = Sequential()
    model.add(Dense(32, use_bias=False, activation='relu', input_dim=12))
    model.add(Dense(16, use_bias=False, activation='relu'))
    model.add(Dense(8, use_bias=False, activation='relu'))
    model.add(Dense(4, use_bias=False, activation='sigmoid'))

    model.compile(loss=binary_crossentropy,
        optimizer=Adam(),
        metrics=['accuracy'])

    return model

# %%
logdir = "logs/"

tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

model = get_compiled_model()
model.fit(X_train, y_train, 
          epochs=500, 
          validation_data=(X_test, y_test),
          callbacks=[tensorboard_callback])
# Out:
# Train on 24552 samples, validate on 12093 samples
# Epoch 1/500
# 24552/24552 [==============================] - 3s 120us/sample - loss: 0.8149 - acc: 0.7712 - val_loss: 0.4600 - val_acc: 0.7938
# Epoch 2/500
# 24552/24552 [==============================] - 2s 73us/sample - loss: 0.4413 - acc: 0.7989 - val_loss: 0.4138 - val_acc: 0.8110
# Epoch 3/500
# 24552/24552 [==============================] - 2s 85us/sample - loss: 0.3991 - acc: 0.8237 - val_loss: 0.4030 - val_acc: 0.8220
# Epoch 4/500
# 24552/24552 [==============================] - 2s 74us/sample - loss: 0.3703 - acc: 0.8404 - val_loss: 0.3458 - val_acc: 0.8568
# Epoch 5/500
# 24552/24552 [==============================] - 2s 73us/sample - loss: 0.3471 - acc: 0.8565 - val_loss: 0.3272 - val_acc: 0.8679
# Epoch 6/500
# 24552/24552 [==============================] - 2s 73us/sample - loss: 0.3280 - acc: 0.8668 - val_loss: 0.3181 - val_acc: 0.8728
# Epoch 7/500
# 24552/24552 [==============================] - 2s 72us/sample - loss: 0.3138 - acc: 0.8758 - val_loss: 0.2928 - val_acc: 0.8897
# Epoch 88/500
# 24552/24552 [==============================] - 2s 71us/sample - loss: 0.0713 - acc: 0.9741 - val_loss: 0.0861 - val_acc: 0.9687
# Epoch 89/500
# 24552/24552 [==============================] - 2s 82us/sample - loss: 0.0655 - acc: 0.9757 - val_loss: 0.0827 - val_acc: 0.9677
# Epoch 90/500
# 24552/24552 [==============================] - 3s 115us/sample - loss: 0.0674 - acc: 0.9750 - val_loss: 0.0925 - val_acc: 0.9655
# Epoch 91/500
# 24032/24552 [============================>.] - ETA: 0s - loss: 0.0693 - acc: 0.9740
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-235-bb985b96e352> in <module>
#       7           epochs=500,
#       8           validation_data=(X_test, y_test),
# ----> 9           callbacks=[tensorboard_callback])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     778           validation_steps=validation_steps,
#     779           validation_freq=validation_freq,
# --> 780           steps_name='steps_per_epoch')
#     781
#     782   def evaluate(self,
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/training_arrays.py in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     407           validation_in_fit=True,
#     408           prepared_feed_values_from_dataset=(val_iterator is not None),
# --> 409           steps_name='validation_steps')
#     410       if not isinstance(val_results, list):
#     411         val_results = [val_results]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/training_arrays.py in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     372         # Callbacks batch end.
#     373         batch_logs = cbks.make_logs(model, batch_logs, batch_outs, mode)
# --> 374         callbacks._call_batch_hook(mode, 'end', batch_index, batch_logs)
#     375         progbar.on_batch_end(batch_index, batch_logs)
#     376
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     249     self._delta_ts[hook_name].append(time.time() - t_before_callbacks)
#     250
# --> 251     delta_t_median = np.median(self._delta_ts[hook_name])
#     252     if (self._delta_t_batch > 0. and
#     253         delta_t_median > 0.95 * self._delta_t_batch and delta_t_median > 0.1):
#
# <__array_function__ internals> in median(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py in median(a, axis, out, overwrite_input, keepdims)
#    3500     """
#    3501     r, k = _ureduce(a, func=_median, axis=axis, out=out,
# -> 3502                     overwrite_input=overwrite_input)
#    3503     if keepdims:
#    3504         return r.reshape(k)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py in _ureduce(a, func, **kwargs)
#    3408         keepdim = (1,) * a.ndim
#    3409
# -> 3410     r = func(a, **kwargs)
#    3411     return r, keepdim
#    3412
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py in _median(a, axis, out, overwrite_input)
#    3533             part = a
#    3534     else:
# -> 3535         part = partition(a, kth, axis=axis)
#    3536
#    3537     if part.shape == ():
#
# <__array_function__ internals> in partition(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in partition(a, kth, axis, kind, order)
#     743     else:
#     744         a = asanyarray(a).copy(order="K")
# --> 745     a.partition(kth, axis=axis, kind=kind, order=order)
#     746     return a
#     747
#
# KeyboardInterrupt:

# %%
score = model.evaluate(X_test, y_test, verbose=0)
print(f'Test loss: {score[0]} / Test accuracy: {score[1]}')
# Out:
# Test loss: 2.8106882325829896 / Test accuracy: 0.8172496557235718

# %%
model.predict(X_test)
# Out:
# array([[4.7162175e-04, 3.6954880e-05, 5.8174133e-05, 9.9928051e-01],
#        [8.0466270e-06, 2.0861626e-07, 5.9604645e-08, 9.9999070e-01],
#        [9.9851233e-01, 9.6017122e-04, 1.1910409e-02, 7.0801377e-04],
#        ...,
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00],
#        [2.0861626e-07, 4.9315691e-03, 9.7365767e-01, 6.0114205e-02],
#        [1.2627478e-04, 1.4151062e-04, 7.3352989e-05, 9.9929273e-01]],
#       dtype=float32)

# %%
# %tensorboard --logdir logs/
# Out:
# Reusing TensorBoard on port 6006 (pid 59072), started 0:23:10 ago. (Use '!kill 59072' to kill it.)
#         <iframe
#             width="100%"
#             height="800"
#             src="http://localhost:6006"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
weights = model.get_weights()
for i in range(len(weights)):
    print(type(weights[i]))
    print(np.shape(weights[i]))
# Out:
# <class 'numpy.ndarray'>
# (12, 32)
# <class 'numpy.ndarray'>
# (32,)
# <class 'numpy.ndarray'>
# (32, 16)
# <class 'numpy.ndarray'>
# (16,)
# <class 'numpy.ndarray'>
# (16, 8)
# <class 'numpy.ndarray'>
# (8,)
# <class 'numpy.ndarray'>
# (8, 4)
# <class 'numpy.ndarray'>
# (4,)

# %%
model.summary()
# Out:
# Model: "sequential_27"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_103 (Dense)            (None, 32)                416
# _________________________________________________________________
# dense_104 (Dense)            (None, 16)                528
# _________________________________________________________________
# dense_105 (Dense)            (None, 8)                 136
# _________________________________________________________________
# dense_106 (Dense)            (None, 4)                 36
# =================================================================
# Total params: 1,116
# Trainable params: 1,116
# Non-trainable params: 0
# _________________________________________________________________

# %%
test_X = np.array([[1., 1.], [2., 2.]])
test_y = np.array([[1., 0.], [0., 2.]])

print("features")
print(test_X)
print("labels")
print(test_y)
print("")

test_model = Sequential()
test_model.add(Dense(2, activation='relu', input_dim=2, use_bias=False))
test_model.add(Dense(2, activation='sigmoid', use_bias=False))

test_model.compile(loss=tf.keras.losses.MeanAbsoluteError(),
                    optimizer=Adam(),
                  metrics=['accuracy'])

test_model.fit(test_X, test_y, epochs=700, verbose=0)

test_model.summary()

print("")
print("-- predict --")
print(test_model.predict(test_X, verbose=1))

test_weights = test_model.get_weights()

print("")
print("-- weights --")

for i in range(len(test_weights)):
    print(f"layer : {i}")
    print(test_weights[i])

def sigmoid(x):
    return (1.0 / (1.0 + np.exp(-x)))

def relu(x):
    return max(x, 0)
    
print("")
print("reproduction")
vectorized_relu = np.vectorize(relu)

layer_1 = np.matmul(test_X, test_weights[0])

layer_1 = vectorized_relu(layer_1)

layer_2 = np.matmul(layer_1, test_weights[1])
layer_2 = sigmoid(layer_2)

print(layer_2)
# Out:
# features
# [[1. 1.]
#  [2. 2.]]
# labels
# [[1. 0.]
#  [0. 2.]]
#
# Model: "sequential_85"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_180 (Dense)            (None, 2)                 4
# _________________________________________________________________
# dense_181 (Dense)            (None, 2)                 4
# =================================================================
# Total params: 8
# Trainable params: 8
# Non-trainable params: 0
# _________________________________________________________________
#
# -- predict --
# 2/2 [==============================] - 0s 141ms/sample
# [[2.5384155e-01 1.0661717e-02]
#  [1.0372952e-01 1.1612192e-04]]
#
# -- weights --
# layer : 0
# [[0.3724537  0.75396734]
#  [0.6224514  1.2540973 ]]
# layer : 1
# [[-1.1770039  -1.667168  ]
#  [ 0.04620339 -1.4300848 ]]
#
# reproduction
# [[2.53841544e-01 1.06617172e-02]
#  [1.03729519e-01 1.16121932e-04]]
